# %%
from manim import *

config.background_color = WHITE

# %%
# %%manim -qm -v WARNING DrawStart
#
# class DrawStart(Scene):
#     def construct(self):
#         self.add(Arrow(start=[-5.5,2.5,0],end=[5.5,2.5,0],color=BLACK))
#
#         self.add(Text("Environments over evolutionary time",color=BLACK,font='Sans', font_size=200).shift(UP*2.1).scale(0.12))
#
#         self.add(Text("Ancestral mutational landscape", color=BLACK, font='Sans',font_size=200).shift([-4,-3,0]).scale(0.12))
#
#         self.add(Text("Evolved mutational landscape", color=BLACK, font='Sans', font_size=200).shift([4,-3,0]).scale(0.12))
#
#         self.add(Arrow(color=BLACK,start=[-4,-0.6,0],end=[-2,-0.6,0]))
#
#         self.add(Circle(color=BLACK,radius=0.2).set_fill(WHITE).shift([-4,-0.6,0]))
#         self.add(Circle(color=BLACK,radius=0.2).set_fill(WHITE).shift([4,-0.6,0]))
# Out:
# Manim Community v0.18.1
